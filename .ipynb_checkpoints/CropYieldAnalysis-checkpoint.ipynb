# %%
## 306 project
#install.packages("dplyr")
library(dplyr)
#install.packages("ggplot2")
library(ggplot2)
#install.packages("tidyverse")
library(tidyverse)
# Out:
# Installing package into ‘/home/jupyter/R/x86_64-pc-linux-gnu-library/4.5’
# (as ‘lib’ is unspecified)
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ lubridate 1.9.4     ✔ tibble    3.3.0
# ✔ purrr     1.2.0     ✔ tidyr     1.3.2
# ✔ readr     2.1.6
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
yield_data = read.csv("cereal-crop-yield-vs-fertilizer-application.csv")
co_data = read.csv("co-emissions-per-capita.csv")
gdp_data = read.csv("gdp-per-capita-worldbank.csv")

# %%
filtered_yield <- filter(yield_data, Year > 2020)
avg_yield <- filtered_yield %>% group_by(Entity) %>% summarize(mean_yield = mean(Cereal.yield))

# %%
filtered_co <- filter(co_data, Year > 2020)
avg_co <- filtered_co %>% group_by(Entity) %>% summarize(mean_co = mean(CO..emissions.per.capita))

# %%
filtered_gdp <- filter(gdp_data, Year > 2020)
avg_gdp <- filtered_gdp %>% group_by(Entity) %>% summarize(mean_gdp = mean(GDP.per.capita))

# %%
combined_data <- avg_yield %>%
  left_join(avg_co, by = "Entity") %>%
  left_join(avg_gdp, by = "Entity") %>% 
drop_na()

# %%
# DATA EXPLORATION:
dim(combined_data)
mean(combined_data$mean_yield)
mean(combined_data$mean_co)
mean(combined_data$mean_gdp)
head(combined_data)
# Out:
# [1] 175   4
# [1] 3.8244
# [1] 4.324488
# [1] 24396.18
#   Entity              mean_yield mean_co   mean_gdp
# 1 Afghanistan         2.238525   0.2512173  2036.563
# 2 Albania             5.167025   1.6391484 19930.963
# 3 Algeria             1.456850   4.2334172 14985.077
# 4 Angola              1.050400   0.5819078  8875.643
# 5 Antigua and Barbuda 1.964225   6.9328015 27883.241
# 6 Argentina           4.769800   3.9764136 27031.915

# %%
## EDA PLOTS
EDA_plot1 <- combined_data %>%
  ggplot(aes(x = mean_co, y = mean_yield)) +
  geom_point() +
  geom_smooth(method = "lm", se = TRUE) +
  labs(
    title = "Mean Cereal Yield vs Mean CO2 Emissions per Capita",
    x = "Mean CO2 Emissions per Capita",
    y = "Mean Cereal Yield"
  )

EDA_plot1

EDA_plot2 <- combined_data %>%
  ggplot(aes(x = mean_gdp, y = mean_yield)) +
  geom_point() +
  geom_smooth(method = "lm", se = TRUE) +
  labs(
    title = "Mean Cereal Yield vs Mean GDP per Capita",
    x = "Mean GDP per Capita",
    y = "Mean Cereal Yield"
  )

EDA_plot2
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# From these plots, it appears highly likely that both GDP per capita and CO₂ emissions per capita are statistically significant. However, the plots look quite similar, so it is worth exploring multicollinearity further. Additionally, the data appear to be left-skewed, suggesting there may be excessive influence from certain observations, particularly those on the right. Finally, the first plot indicates that there may be heteroskedasticity in the data.

# %%
### Fiting a model
